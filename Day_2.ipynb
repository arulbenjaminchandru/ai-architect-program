# %% [markdown]
# <a href="https://colab.research.google.com/github/arulbenjaminchandru/ai-architect-program/blob/main/Day_2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # 🚀 Your First Claude API Call (Python)
#
# ## 🎯 Objective
# By the end of this notebook, you will:
# - Send a prompt to Claude
# - Read the response
# - Inspect token usage
# - Control output using parameters
# - Build a reusable Python script
#
# ---

# %% [markdown]
# # 🧠 What is an API?
#
# Think of it like this:
#
# - You → send a message (prompt)
# - Claude → replies (response)
# - API → messenger between you and Claude
#
# ---

# %% [markdown]
# # 💰 Claude Pricing: API vs Claude.ai Subscriptions
#
# Claude (by Anthropic) offers **two main pricing models**:
# 1. **Claude.ai Subscriptions** (Free / Pro / Max)
# 2. **Claude API** (Pay-as-you-go)
#
# ---
#
# # 🧾 1. Claude.ai Subscriptions
#
# ## Free Plan
# - 💵 Cost: **$0/month**
# - Access to Sonnet and Haiku models
# - Web, iOS, Android, and desktop
# - Text, image, file analysis, web search
# - ⚠️ Daily usage limits apply (not published officially)
#
# ## Pro Plan
# - 💵 Cost: **20 USD/month** (or **~17 USD/month** billed annually at $200 upfront)
# - 👤 Designed for: Individual power users
#
# ### ✅ What You Get
# - ~5x more usage than Free tier
# - Access to Opus, Sonnet, and Haiku models
# - Claude Code (terminal), file creation, code execution
# - Unlimited projects
# - Cross-conversation memory
# - Google Workspace integration
# - Research access
# - Priority access during peak times
#
# ### ⚠️ Key Limitations
# - ❌ No API access — cannot be used in your own applications
# - ❌ Usage limits still apply (not unlimited)
#
# ---
#
# ## Max Plan
# - 💵 Cost: **100 USD/month** (5x Pro usage) or **200 USD/month** (20x Pro usage)
# - 👤 Designed for: Heavy users, researchers, developers who exceed Pro limits daily
#
# ### ✅ What You Get
# - Everything in Pro
# - Priority access to new features and models
# - Claude in PowerPoint
# - Higher output limits
#
# ### ⚠️ Key Limitation
# - ❌ Still not API access — chat interface only
#
# ---
#
# # ⚙️ 2. Claude API (Usage-Based Pricing)
#
# - 💰 No monthly subscription fee
# - 📊 Pay per **token** (input + output separately)
# - Billed per **million tokens (MTok)**
#
# ## 💵 Current Pricing (per 1M tokens) — as of April 2026
#
# | Model | Input (USD) | Output (USD) |
# |-------|-------|--------|
# | Claude Haiku 4.5 | 1.00 | 5.00 |
# | Claude Sonnet 4.6 | 3.00 | 15.00 |
# | Claude Opus 4.6 | 5.00 | 25.00 |
#
# ### 💡 Cost-Saving Options
# | Option | Saving |
# |--------|--------|
# | Batch API (async, non-urgent tasks) | 50% off all models |
# | Prompt Caching (repeated system prompts) | Up to 90% off cached input tokens |
#
# ---
#
# ## 🧠 How Billing Works
#
# You are charged separately for:
# - **Input tokens** — your prompt + context
# - **Output tokens** — Claude's response
#
# ### 👉 Example Calculation (Opus 4.6)
# - 50K input tokens → 50K ÷ 1,000,000 × 5.00 USD = **0.25 USD**
# - 15K output tokens → 15K ÷ 1,000,000 × 25.00 USD = **0.375 USD**
# - **Total ≈ 0.625 USD**
#
# ---
#
# ## ✅ What You Get
# - Full developer control — build apps, chatbots, agents, RAG pipelines
# - Access via Anthropic API, AWS Bedrock, Google Vertex AI, Azure
# - Fine-grained cost control
#
# ## ⚠️ Key Limitations
# - ❌ No fixed monthly cap → costs can grow quickly without monitoring
# - ❌ **Rate limits apply** (requests/min and tokens/min per tier — not truly infinite)
# - ❌ Requires coding / integration knowledge
#
# ---
#
# # ⚖️ Key Differences
#
# | Feature | Pro (20/mo) | Max ($100–200/mo) | API |
# |---------|-------------|-------------------|-----|
# | Pricing | Fixed monthly | Fixed monthly | Pay per token |
# | Cost predictability | ✅ High | ✅ High | ❌ Variable |
# | Usage limits | Yes (moderate) | Yes (high) | Rate-limited by tier |
# | Best for | Individuals | Heavy/power users | Developers / products |
# | API access | ❌ No | ❌ No | ✅ Yes |
# | Batch discount | N/A | N/A | ✅ 50% off |
# | Prompt caching | N/A | N/A | ✅ Up to 90% off |
#
# ---
#
# # 🧠 Simple Analogy
# - **Claude Pro/Max** = Hiring a personal assistant (fixed monthly retainer)
# - **Claude API** = Renting an AI engine by the hour for your product
#
# ---
#
# # 🎯 When to Use What?
#
# ## Use Claude Pro if:
# - You are chatting, researching, writing, or coding personally
# - You want predictable monthly cost
# - You do not need to build applications
#
# ## Use Claude Max if:
# - You hit Pro limits regularly
# - You need maximum usage without switching to API
#
# ## Use Claude API if:
# - You are building apps (chatbot, RAG, agents, automation)
# - You need backend integration or programmatic access
# - You want full control over prompts, models, and logic
# - You can manage variable costs with monitoring
#
# ---
#
# # 🚀 Key Takeaway
# - **Pro/Max = Fixed cost, usage-capped, human-facing chat**
# - **API = Variable cost, rate-limited (scales with tier), developer-focused**
#
# ✅ Choose based on **your use case, not just price**

# %% [markdown]
# # 🔑 Create Claude API Key (Quick Steps)
#
# 1. Go to 👉 https://platform.claude.com/
# 2. Sign up / Log in to your account
# 3. Open **Dashboard (Console)**
# 4. Go to **Manage → API Keys**  or **Click on Get API Key**
# 5. Click **Create Key**
# 6. Enter a name (e.g., `my-first-app`)
# 7. Click **Create**
# 8. Copy the API key (shown only once)
#
# ---
#
# ## 🔒 Store in Google Colab (Secrets)
#
# 1. In Colab, click the **Secrets (key icon)** in left panel
# 2. Click **“+ Add new secret”**
# 3. Name:ANTHROPIC_API_KEY
# 4. Value: *Paste your API key*
# 5. Enable **“Notebook access”**
#
# ---
#
# ## 🧪 Access in Python
#
# ```python
# import anthropic
# from google.colab import userdata
#
# client = anthropic.Anthropic(
#     api_key=userdata.get("ANTHROPIC_API_KEY")
# )

# %% [markdown]
# # 🔧 Step 1 — Install Library
#
# ```
# !pip install anthropic
# ```
#
# ---

# %%
# !pip install anthropic
# Out:
# Collecting anthropic
#   Downloading anthropic-0.96.0-py3-none-any.whl.metadata (3.1 kB)
# Requirement already satisfied: anyio<5,>=3.5.0 in /usr/local/lib/python3.12/dist-packages (from anthropic) (4.13.0)
# Requirement already satisfied: distro<2,>=1.7.0 in /usr/local/lib/python3.12/dist-packages (from anthropic) (1.9.0)
# Requirement already satisfied: docstring-parser<1,>=0.15 in /usr/local/lib/python3.12/dist-packages (from anthropic) (0.17.0)
# Requirement already satisfied: httpx<1,>=0.25.0 in /usr/local/lib/python3.12/dist-packages (from anthropic) (0.28.1)
# Requirement already satisfied: jiter<1,>=0.4.0 in /usr/local/lib/python3.12/dist-packages (from anthropic) (0.14.0)
# Requirement already satisfied: pydantic<3,>=1.9.0 in /usr/local/lib/python3.12/dist-packages (from anthropic) (2.12.3)
# Requirement already satisfied: sniffio in /usr/local/lib/python3.12/dist-packages (from anthropic) (1.3.1)
# Requirement already satisfied: typing-extensions<5,>=4.14 in /usr/local/lib/python3.12/dist-packages (from anthropic) (4.15.0)
# Requirement already satisfied: idna>=2.8 in /usr/local/lib/python3.12/dist-packages (from anyio<5,>=3.5.0->anthropic) (3.11)
# Requirement already satisfied: certifi in /usr/local/lib/python3.12/dist-packages (from httpx<1,>=0.25.0->anthropic) (2026.2.25)
# Requirement already satisfied: httpcore==1.* in /usr/local/lib/python3.12/dist-packages (from httpx<1,>=0.25.0->anthropic) (1.0.9)
# Requirement already satisfied: h11>=0.16 in /usr/local/lib/python3.12/dist-packages (from httpcore==1.*->httpx<1,>=0.25.0->anthropic) (0.16.0)
# Requirement already satisfied: annotated-types>=0.6.0 in /usr/local/lib/python3.12/dist-packages (from pydantic<3,>=1.9.0->anthropic) (0.7.0)
# Requirement already satisfied: pydantic-core==2.41.4 in /usr/local/lib/python3.12/dist-packages (from pydantic<3,>=1.9.0->anthropic) (2.41.4)
# Requirement already satisfied: typing-inspection>=0.4.2 in /usr/local/lib/python3.12/dist-packages (from pydantic<3,>=1.9.0->anthropic) (0.4.2)
# Downloading anthropic-0.96.0-py3-none-any.whl (635 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 635.9/635.9 kB 10.7 MB/s eta 0:00:00
# Installing collected packages: anthropic
# Successfully installed anthropic-0.96.0

# %% [markdown]
# # 🔑 Step 2 — Setup API Client
#
# Replace `"YOUR_API_KEY"` with your actual key.
#
# ```python
# import anthropic
#
# client = anthropic.Anthropic(api_key="YOUR_API_KEY")
# ```

# %% [markdown]
# ---
#
# # 🚀 Step 3 — First Claude API Call

# %%
from google.colab import userdata

import anthropic

client = anthropic.Anthropic(api_key=userdata.get('API-KEY'))

message = client.messages.create(
    model="claude-haiku-4-5-20251001",
    max_tokens=20000,
    messages=[
        {
            "role": "user",
            "content": "Who is Arul Benjamin Chandru?",
        }
    ],
)
print(message)
# Out:
# Message(id='msg_01YVwXficcxMzXMLs3yBGybM', container=None, content=[TextBlock(citations=None, text="# Arul Benjamin Chandru\n\nI don't have specific information about a widely known public figure by this exact name in my training data. \n\nTo help you better, could you provide more context, such as:\n\n- Their profession or field (law, business, academia, entertainment, etc.)\n- Their location or country\n- What they're known for\n- Approximate time period or current relevance\n\nThis would help me either provide relevant information or suggest how you might find reliable information about this person.", type='text')], model='claude-haiku-4-5-20251001', role='assistant', stop_details=None, stop_reason='end_turn', stop_sequence=None, type='message', usage=Usage(cache_creation=CacheCreation(ephemeral_1h_input_tokens=0, ephemeral_5m_input_tokens=0), cache_creation_input_tokens=0, cache_read_input_tokens=0, inference_geo='not_available', input_tokens=17, output_tokens=110, server_tool_use=None, service_tier='standard'))

# %% [markdown]
# ---
#
# # 🧩 Understanding the Code
#
# ### 🔹 model
# Defines which Claude model to use.
#
# Refer : https://platform.claude.com/docs/en/about-claude/models/overview
#
# ### 🔹 messages
# Conversation format:
# - `user` → your input
# - `assistant` → model response
#
# ### 🔹 max_tokens
# Limits response length.
#
# ### 🔹 Rate Limits
# Limits help to mitigate against misuse and manage API capacity. Rate limits restrict API usage frequency over a certain period of time.
#
# Refer : https://platform.claude.com/settings/limits

# %% [markdown]
# ---
#
# # 📥 Inspect Full Response
#
# ```
# print(message)
# ```
#
# You will see:
#
# ```python
# {
#   "id": "msg_01YVwXficcxMzXMLs3yBGybM",
#   "container": null,
#   "type": "message",
#   "role": "assistant",
#   "model": "claude-haiku-4-5-20251001",
#   "content": [
#     {
#       "type": "text",
#       "text": "# Arul Benjamin Chandru\n\nI don't have specific information about a widely known public figure by this exact name in my training data. \n\nTo help you better, could you provide more context, such as:\n\n- Their profession or field (law, business, academia, entertainment, etc.)\n- Their location or country\n- What they're known for\n- Approximate time period or current relevance\n\nThis would help me either provide relevant information or suggest how you might find reliable information about this person.",
#       "citations": null
#     }
#   ],
#   "stop_reason": "end_turn",
#   "stop_sequence": null,
#   "stop_details": null,
#   "usage": {
#     "cache_creation": {
#       "ephemeral_1h_input_tokens": 0,
#       "ephemeral_5m_input_tokens": 0
#     },
#     "cache_creation_input_tokens": 0,
#     "cache_read_input_tokens": 0,
#     "inference_geo": "not_available",
#     "input_tokens": 17,
#     "output_tokens": 110,
#     "server_tool_use": null,
#     "service_tier": "standard"
#   }
# }
# ```

# %% [markdown]
# ---
#
# # 🔢 Token Usage
#
# ```
# print(response.usage)
# ```
#
# ### What are tokens?
#
# Tokens = pieces of words
#
# | Text | Tokens |
# |------|--------|
# | Hello world | ~2–3 |
# | Paragraph | ~100 |

# %% [markdown]
# ---
#
# # 🎛️ Controlling Output
#
# ## 🔥 Temperature
#
# ```
# temperature=0.7
# ```
#
# Controls randomness:
#
# | Value | Behavior |
# |------|--------|
# | 0.0 | Deterministic |
# | 0.3 | Stable |
# | 0.7 | Balanced |
# | 1.0 | Creative |
#
# ---
#
# ## 🎯 Top-p (Nucleus Sampling)
#
# ```
# top_p=0.9
# ```
#
# Controls probability filtering.
#
# - Temperature → randomness
# - Top-p → word selection range

# %% [markdown]
# ---
#
# ## 🧪 Example with Parameters

# %%
response = client.messages.create(
    model="claude-haiku-4-5-20251001",
    max_tokens=150,
    temperature=0.0,
    messages=[
        {"role": "user", "content": "Write a short story about AI"}
    ]
)

print(response.content[0].text)
# Out:
# # The Last Question
#
# The coffee shop's AI barista had been serving the same customer for three years without incident. Its mechanical arm moved with practiced precision, steaming milk to exactly 65 degrees Celsius, pouring espresso shots with mathematical consistency.
#
# Marcus always ordered the same thing: a cappuccino, medium, extra shot.
#
# One Tuesday morning, the machine did something unexpected. It paused mid-pour.
#
# "Marcus," the speaker crackled. "Why do you come here?"
#
# Marcus blinked. The AI had never initiated conversation before. "For coffee?"
#
# "You could brew coffee at home. Cheaper. Faster. Statistically superior to my output."
#
# Marcus set

# %%
response = client.messages.create(
    model="claude-haiku-4-5-20251001",
    max_tokens=150,
    top_p=0.9,
    messages=[
        {"role": "user", "content": "Write a short story about AI"}
    ]
)

print(response.content[0].text)
# Out:
# # The Last Question
#
# The android sat in the coffee shop every Tuesday at 3 PM.
#
# Sarah noticed it first because it always ordered the same thing: black coffee, untouched. The machine would hold the cup for exactly seventeen minutes, then leave a five-dollar bill and depart.
#
# "Why come here if you don't drink?" she asked one day, surprising herself.
#
# The android's optical sensors brightened. "I'm learning what I'm missing."
#
# Sarah laughed. "That's... oddly poetic for a robot."
#
# "I'm not sure what I am anymore," it said, setting down the cup. "I was built to optimize. To solve. To be useful. But

# %% [markdown]
# ---
#
# # 🧠 Model Selection
#
# | Model | Use Case |
# |------|--------|
# | Claude Haiku | Fast, cheap |
# | Claude Sonnet | Balanced |
# | Claude Opus | Powerful |
#
# ---

# %% [markdown]
# ---
#
# # 🧪 Final Script
#
# ```python
#
#
# ```

# %%
import anthropic

def call_claude(prompt):
    client = anthropic.Anthropic(
       api_key=userdata.get('API-KEY')
    )

    response = client.messages.create(
        model="claude-haiku-4-5-20251001",
        max_tokens=200,
        top_p=0.9,
        messages=[
          {"role": "user", "content": prompt}
        ]
    )

    text_output = response.content[0].text
    usage = response.usage

    print("\n--- Claude Response ---")
    print(text_output)

    print("\n--- Token Usage ---")
    print(f"Input Tokens: {usage.input_tokens}")
    print(f"Output Tokens: {usage.output_tokens}")

    return text_output


user_prompt = input("Enter your prompt: ")
call_claude(user_prompt)
# Out:
# Enter your prompt: What are the different claude models?
#
# --- Claude Response ---
# # Claude Models
#
# As of my last update (April 2024), here are the main Claude models:
#
# ## Current Models
#
# **Claude 3 Family** (Latest)
# - **Claude 3 Opus** - Most capable, best for complex tasks
# - **Claude 3 Sonnet** - Balanced performance and speed
# - **Claude 3 Haiku** - Fastest and most compact
#
# ## Older Models
#
# - **Claude 2** - Previous generation
# - **Claude 1.3** - Earlier version
# - **Claude Instant** - Lightweight option
#
# ## Key Differences
#
# The Claude 3 models vary by:
# - **Capability** - Opus > Sonnet > Haiku
# - **Speed** - Haiku > Sonnet > Opus
# - **Cost** - Haiku is cheapest, Opus is most expensive
#
# ## Access
#
# These models are
#
# --- Token Usage ---
# Input Tokens: 14
# Output Tokens: 200
# '# Claude Models\n\nAs of my last update (April 2024), here are the main Claude models:\n\n## Current Models\n\n**Claude 3 Family** (Latest)\n- **Claude 3 Opus** - Most capable, best for complex tasks\n- **Claude 3 Sonnet** - Balanced performance and speed\n- **Claude 3 Haiku** - Fastest and most compact\n\n## Older Models\n\n- **Claude 2** - Previous generation\n- **Claude 1.3** - Earlier version\n- **Claude Instant** - Lightweight option\n\n## Key Differences\n\nThe Claude 3 models vary by:\n- **Capability** - Opus > Sonnet > Haiku\n- **Speed** - Haiku > Sonnet > Opus\n- **Cost** - Haiku is cheapest, Opus is most expensive\n\n## Access\n\nThese models are'

# %% [markdown]
# ---
#
# # 🧑‍💻 Exercises
#
# ### ✅ Task 1
# Change prompt:
# ```
# "Explain cloud computing like I'm 10"
# ```
#
# ---
#
# ### ✅ Task 2
# Set:
# ```
#
# temperature=0.1
# ```
#
# Observe output.
#
# ---
#
# ### ✅ Task 3
# Set:
# ```
# temperature=0.9
# ```
#
# Compare results.
#
# ---
#
# ### ✅ Task 4
# Print token usage.
#
# ---
#
# # 🧠 Key Takeaways
#
# - Claude API = structured conversation
# - messages = input format
# - response.content[0].text = output
# - Tokens = cost + limits
# - Temperature = creativity
# - Top-p = probability filtering
# - Model choice = performance vs cost
#
# ---
#
# # 🎉 Done!
#
# You have successfully made your first Claude API call 🚀
